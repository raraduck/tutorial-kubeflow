# %%
import torchvision

torchvision.datasets.FashionMNIST(
    root="/home/jovyan/private-nas/data",
    train=True,
    download=True
)
torchvision.datasets.FashionMNIST(
    root="/home/jovyan/private-nas/data",
    train=False,
    download=True
)

# 확인
import os
for f in os.listdir("/home/jovyan/private-nas/data/FashionMNIST/raw"):
    print(f)
# Out:
# 100%|██████████| 26.4M/26.4M [00:07<00:00, 3.62MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 110kB/s]
# 100%|██████████| 4.42M/4.42M [00:02<00:00, 1.99MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 7.84MB/s]
# train-images-idx3-ubyte.gz
# train-images-idx3-ubyte
# train-labels-idx1-ubyte.gz
# train-labels-idx1-ubyte
# t10k-images-idx3-ubyte.gz
# t10k-images-idx3-ubyte
# t10k-labels-idx1-ubyte.gz
# t10k-labels-idx1-ubyte
